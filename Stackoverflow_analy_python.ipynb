# %%
import pandas
from pandas import read_csv

# %%
stackoverflow = read_csv('/Users/choejiho/modified_survey_results.csv')
stackoverflow_dsc_converted_comp = stackoverflow.sort_values('ConvertedCompYearly', ascending=False)
stackoverflow_dsc_converted_comp
# Out:
#        ResponseId                                         MainBranch  \
# 0           40305                     I am a developer by profession
# 1             202                     I am a developer by profession
# 2           62027                     I am a developer by profession
# 3           70523                     I am a developer by profession
# 4           61044                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
# stackoverflow_dsc_converted_comp.to_csv('/Users/choejiho/Downloads/modified_survey_results.csv', index=False)

# %% [markdown]
# <!-- 특정 조건을 만족하는 행의 인덱스 찾기 -->

# %%
# compindex = stackoverflow_dsc_converted_comp[stackoverflow_dsc_converted_comp['ConvertedCompYearly'] <= 100].index
# print(compindex)
# Out:
# Index([68607, 64843, 58935, 40717, 14706, 27332, 47265, 33703, 35576, 33505,
#        ...
#        63170, 51920,  6123, 36435, 32332, 19912, 65742, 39915, 64366, 52005],
#       dtype='int64', length=139)

# %% [markdown]
# <!-- 위 조건 만족하는 인덱스 찾고 행 삭제 처리 -->

# %%
# stackoverflow_dsc_converted_comp.drop(compindex)
# Out:
#        ResponseId                                         MainBranch  \
# 40304       40305                     I am a developer by profession
# 201           202                     I am a developer by profession
# 62026       62027                     I am a developer by profession
# 70522       70523                     I am a developer by profession
# 61043       61044                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 40304  Independent contractor, freelancer, or self-em...
# ...
