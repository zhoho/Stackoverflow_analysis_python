# %%
import pandas
import numpy as np
import matplotlib as mpl           # 그래프를 그리는 패키지
import matplotlib.pyplot as plt    # 그래프를 그리는 패키지
from pandas import read_csv
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
stackoverflow = read_csv('/Users/choejiho/modified_survey_results.csv')
stackoverflow_dsc_converted_comp = stackoverflow.sort_values('ConvertedCompYearly', ascending=False)
stackoverflow_dsc_converted_comp
# Out:
#        ResponseId                      MainBranch  \
# 0             202  I am a developer by profession
# 1           62027  I am a developer by profession
# 2           70523  I am a developer by profession
# 3           61044  I am a developer by profession
# 4           18923  I am a developer by profession
# ...           ...                             ...
# 37926        1681  I am a developer by profession
# 37927        9519  I am a developer by profession
# 37928       51178  I am a developer by profession
# 37929       69097  I am a developer by profession
# 37930       61113  I am a developer by profession
#
#                                               Employment  \
# 0                                    Employed, full-time
# 1                                    Employed, full-time
# 2      Independent contractor, freelancer, or self-em...
# 3                                    I prefer not to say
# 4                                    Employed, full-time
# ...

# %%
# stackoverflow_dsc_converted_comp.to_csv('/Users/choejiho/Downloads/modified_survey_results.csv', index=False)

# %% [markdown]
# <!-- 특정 조건을 만족하는 행의 인덱스 찾기 -->

# %%
# compindex = stackoverflow_dsc_converted_comp[stackoverflow_dsc_converted_comp['ConvertedCompYearly'] <= 100].index
# print(compindex)

# %%
converted_comp = stackoverflow_dsc_converted_comp['ConvertedCompYearly']
# converted_comp = [110.0, 20.0, 30.0, 40.0, 50.0, 610.0, 70.0, 80.0, 90.0, 100.0, 110.0]

# %%
# 구간별 빈도수 계산
bins = np.arange(100, 5000000, 100000)  # 0부터 100까지 10의 단위로 구간을 나눔
bin_values, _ = np.histogram(converted_comp, bins=bins)

# 그래프 그리기
plt.bar(range(len(bin_values)), bin_values)

# x축 레이블과 제목 추가
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.title('Distribution of ConvertedCompYearly')

# x축 레이블 설정
x_labels = [f'{bins[i]}-{bins[i+1]}' for i in range(len(bins)-1)]
plt.xticks(range(len(bin_values)), x_labels, rotation=45)

# 그래프 보여주기
plt.show()

# %%
bins = np.arange(100, 100000, 5000)  # 0부터 100까지 10의 단위로 구간을 나눔
bin_values, _ = np.histogram(converted_comp, bins=bins)

# 그래프 그리기
plt.bar(range(len(bin_values)), bin_values)

# x축 레이블과 제목 추가
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.title('Distribution of ConvertedCompYearly')

# x축 레이블 설정
x_labels = [f'{bins[i]}-{bins[i+1]}' for i in range(len(bins)-1)]
plt.xticks(range(len(bin_values)), x_labels, rotation=45)

# 그래프 보여주기
plt.show()
