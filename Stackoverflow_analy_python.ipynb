# %%
from pandas import read_csv

# %%
stackoverflow = read_csv('/Users/choejiho/Downloads/stack-overflow-developer-survey-2022 2/survey_results_public.csv')
stackoverflow
# Out:
#        ResponseId  ... ConvertedCompYearly
# 0               1  ...                 NaN
# 1               2  ...                 NaN
# 2               3  ...             40205.0
# 3               4  ...            215232.0
# 4               5  ...                 NaN
# ...           ...  ...                 ...
# 73263       73264  ...                 NaN
# 73264       73265  ...                 NaN
# 73265       73266  ...                 NaN
# 73266       73267  ...                 NaN
# 73267       73268  ...                 NaN
#
# [73268 rows x 79 columns]
